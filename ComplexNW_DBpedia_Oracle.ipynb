# %% [markdown]
# ## Comparing KGs to real-world complex networks
#
# Using a portion of *DBpedia* as target KG

# %% [markdown]
# # Environment Setup
#
# Install & imports

# %%
# Install required packages
import sys
# !pip install -q rdflib networkx matplotlib
# !{sys.executable} -m pip install rdflib networkx matplotlib --user

# Imports
from rdflib import Graph as RDFGraph
from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph
import networkx as nx
from networkx import Graph as NXGraph
import matplotlib.pyplot as plt
import statistics
import collections
# Out:
# Requirement already satisfied: rdflib in /usr/local/lib/python3.10/dist-packages (7.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)

# %% [markdown]
# Auxiliary functions

# %%
def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)

def histogram(l):
    degree_sequence = sorted([d for n, d in list(l.items())], reverse=True)
    degreeCount = collections.Counter(degree_sequence)
    deg, cnt = zip(*degreeCount.items())
    print(deg, cnt)

    fig, ax = plt.subplots()
    plt.bar(deg, cnt, width=0.80, color='b')

    plt.title("Histogram")
    plt.ylabel("Count")
    plt.xlabel("Value")
    ax.set_xticks([d + 0.4 for d in deg])
    ax.set_xticklabels(deg)

    plt.show()

def degree_histogram_directed(G, in_degree=False, out_degree=False):
    """Return a list of the frequency of each degree value.

    Parameters
    ----------
    G : Networkx graph
       A graph
    in_degree : bool
    out_degree : bool

    Returns
    -------
    hist : list
       A list of frequencies of degrees.
       The degree values are the index in the list.

    Notes
    -----
    Note: the bins are width one, hence len(list) can be large
    (Order(number_of_edges))

    Ref.: https://stackoverflow.com/a/62662992
    """
    nodes = G.nodes()
    if in_degree:
        in_degree = dict(G.in_degree())
        degseq=[in_degree.get(k,0) for k in nodes]
    elif out_degree:
        out_degree = dict(G.out_degree())
        degseq=[out_degree.get(k,0) for k in nodes]
    else:
        degseq=[v for k, v in G.degree()]
    dmax=max(degseq)+1
    freq= [ 0 for d in range(dmax) ]
    for d in degseq:
        freq[d] += 1
    return freq

# %% [markdown]
# ## Loading RDF model
#
# Pointing to a remote Turtle (*.ttl) file.

# %%
rg = RDFGraph()
rg.parse('https://dbpedia.org/data/Oracle_Corporation.ttl', format='ttl') # Turtle format

print("rdflib Graph loaded successfully with {} triples".format(len(rg)))
# Out:
# rdflib Graph loaded successfully with 2577 triples

# %% [markdown]
# ## Converting rdflib.Graph to networkx.MultiDiGraph
#
# KGs are directed graphs with the possibility of multiple paralell edges.

# %%
# Conversion of rdflib.Graph to networkx.MultiDiGraph
KG = rdflib_to_networkx_multidigraph(rg)
print("networkx Graph loaded successfully with length {}".format(len(KG)))
# Out:
# networkx Graph loaded successfully with length 2143

# %% [markdown]
# # General Network Metrics
#
# Network size and density

# %%
# Network size
print("NETWORK SIZE")
print("============")
print("The network has {} nodes and {} edges".format(KG.number_of_nodes(), KG.number_of_edges()))
print()

# Density
print("DENSITY")
print("============")
print("The network density is {}".format(nx.density(KG)))
print()
# Out:
# NETWORK SIZE
# ============
# The network has 2143 nodes and 2577 edges
#
# DENSITY
# ============
# The network density is 0.0005614004817979455

# %% [markdown]
# # Scale-free Networks
#
# {in, out}-degree distributions -- Is it Poisson's or Power-law alike?

# %%
in_degree_freq = degree_histogram_directed(KG, in_degree=True)
out_degree_freq = degree_histogram_directed(KG, out_degree=True)
degrees = range(len(in_degree_freq))
plt.figure(figsize=(12, 8))
plt.loglog(range(len(in_degree_freq)), in_degree_freq, 'go-', label='in-degree')
plt.loglog(range(len(out_degree_freq)), out_degree_freq, 'bo-', label='out-degree')
plt.xlabel('Degree')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Are there HUBS available?

# %%
h, a = nx.hits(KG)

print("Hubs:")
print(sorted(h.items(), key=lambda x:x[1], reverse=True)) # Hubs - estimates the node value based on outgoing links.
print("The mean is {}, with stdev {}".format(mean(h.values()), statistics.stdev(h.values())))
print("The greatest hub is {}, with value {}".format(max(h, key=h.get), max(h.values())))
print("")
print("Authorities:")
print(sorted(a.items(), key=lambda x:x[1], reverse=True)) # Authorities - estimates the node value based on the incoming links
print("The mean is {}, with stdev {}".format(mean(a.values()), statistics.stdev(a.values())))
print("The greatest authority is {}, with value {}".format(max(a, key=a.get), max(a.values())))
# Out:
# Hubs:
# [(rdflib.term.URIRef('http://dbpedia.org/resource/PeopleSoft'), 0.003616029862584557), (rdflib.term.URIRef('http://dbpedia.org/resource/Vantive'), 0.0025828784732746836), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Multimedia'), 0.0025828784732746836), (rdflib.term.URIRef('http://dbpedia.org/resource/Sun_Microsystems'), 0.0020663027786197467), (rdflib.term.URIRef('http://dbpedia.org/resource/BlueKai'), 0.0020663027786197467), (rdflib.term.URIRef('http://dbpedia.org/resource/Wercker'), 0.0020663027786197467), (rdflib.term.URIRef('http://dbpedia.org/resource/RightNow_Technologies'), 0.0020663027786197467), (rdflib.term.URIRef('http://dbpedia.org/resource/Java_Desktop_System'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Cerner'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_WebLogic_Server'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_iPlanet_Web_Proxy_Server'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Application_Server'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/MySQL_AB'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_SQL_Developer'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/OpenOffice.org'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Data_Mining'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Zero_Data_Loss_Recovery_Appliance'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/VisualVM'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/JD_Edwards'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Tcov'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Advertising_and_Customer_Experience_(CX)'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Monty_Taylor'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Endeca'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Sun_Ray'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Financial_Services_Software'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/DTrace'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Tuxedo_(software)'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/James_G._Mitchell'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Designer'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/AddThis'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/FatWire'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Spatial_and_Graph'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Cloud_Enterprise_Resource_Planning'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/PeopleTools'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Discoverer'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_NoSQL_Database'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Keith_Bostic_(software_engineer)'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_VDI'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/VirtualBox'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Project_Phobos'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Siebel_Systems'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Media_Objects'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/resource/Art_Technology_Group'), 0.00154972708396481), (rdflib.term.URIRef('http://dbpedia.org/re ...
# The mean is 0.0004666355576294852, with stdev 0.0003469608068066113
# The greatest hub is http://dbpedia.org/resource/PeopleSoft, with value 0.003616029862584557
#
# Authorities:
# [(rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Corporation'), 0.5993321506115107), (rdflib.term.Literal('Oracle Corporation', lang='en'), 0.0018722796700396723), (rdflib.term.Literal('ORCL', lang='en'), 0.0018722796700396717), (rdflib.term.URIRef('https://www.oracle.com/%7Coracle.com'), 0.0018722796700396704), (rdflib.term.URIRef('http://dbpedia.org/resource/Application_software'), 0.00187227967003967), (rdflib.term.URIRef('http://dbpedia.org/resource/Cloud_computing'), 0.0018722796700396688), (rdflib.term.URIRef('http://dbpedia.org/resource/Public_company'), 0.0018722796700396662), (rdflib.term.URIRef('http://dbpedia.org/resource/List_of_acquisitions_by_Oracle'), 0.0018722796700396639), (rdflib.term.Literal('Is comhlacht ríomhaireachta é Oracle Corporation atá lonnaithe i Redwood Shores, California, SAM. Cé go bhfuil réimse táirgí bhogearraí ag an gcomhlacht, tá clú bainte amach aige mar gheall ar a bhunachar sonraí, faoin ainm céanna. Is é Larry Ellison an príomhoifigeach feidhmiúcháin ó chuir sé tús leis an gcomhlacht i 1977.', lang='ga'), 0.001248186446693123), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Companies_listed_on_the_New_York_Stock_Exchange'), 0.0012481864466931207), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:American_companies_established_in_1977'), 0.0012481864466931207), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Data_companies'), 0.00124818644669312), (rdflib.term.URIRef('http://dbpedia.org/resource/S&P_500'), 0.0012481864466931183), (rdflib.term.Literal('Oracle Corporation (NASDAQ: ORCL) és una companyia que desenvolupa programari per gestionar empreses i administrar bases de dades electròniques, i productes relacionats. Fundada el 1977, és una companyia líder en el seu sector. El 2005, tenia al voltant de 50.000 empleats en 145 països.', lang='ca'), 0.0012481864466931183), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Software_companies_established_in_1977'), 0.0012481864466931181), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Customer_relationship_management_software_companies'), 0.0012481864466931181), (rdflib.term.URIRef('http://dbpedia.org/resource/Workstation'), 0.0012481864466931175), (rdflib.term.Literal('甲骨文公司（英語：Oracle）是一間全球性的大型企業科技軟件公司，总部位于美国得克薩斯州奧斯汀。現任董事長兼CTO為公司創辦人劳伦斯·埃里森，CEO為凱芝。至2019年，甲骨文是繼微软後，全球收入第二多的软件公司，主要經營企業金融經營資料庫建檔等服務。例如銷售時點情報系統，供應鏈管理，人力資源績效分析等', lang='zh'), 0.0012481864466931173), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Oracle_Corporation'), 0.0012481864466931168), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Database'), 0.0012481864466931164), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Human_resource_management_software'), 0.0012481864466931162), (rdflib.term.URIRef('http://dbpedia.org/resource/Server_(computing)'), 0.001248186446693116), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Cloud_computing_providers'), 0.0012481864466931157), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Companies_formerly_listed_on_the_Nasdaq'), 0.0012481864466931155), (rdflib.term.URIRef('http://dbpedia.org/resource/S&P_100'), 0.0012481864466931147), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Development_software_companies'), 0.0012481864466931147), (rdflib.term.Literal('Oracle Corporation is een Amerikaans softwarebedrijf genoteerd aan de New York Stock Exchange. Oprichter Larry Ellison is voorzitter van het bedrijf. Het hoofdkantoor is in Austin (Texas).', lang='nl'), 0.0012481864466931144), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Computer_companies_established_in_1977'), 0.0012481864466931144), (rdflib.term.Literal('Oracle Corporation är ett av de största mjukvaruföretagen i världen. Företaget grundades 1977 av Larry Ellison, Bob Miner och Ed Oates. Oracle har 132 000 anställda och omsätter nästan 40,5 miljarder dollar.', lang='sv'), 0.0012481864466931144), (rdflib.term.URIRef('http://dbpedia.org/resource/Category:Software_comp ...
# The mean is 0.0004666355576294911, with stdev 0.012946793169763491
# The greatest authority is http://dbpedia.org/resource/Oracle_Corporation, with value 0.5993321506115107

# %% [markdown]
# # Communities
#
# Check for communities using the Clauset-Newman-Moore Algorithm (greedy modularity - applicable to directed graphs)

# %%
comms = nx.community.greedy_modularity_communities(KG)

print(f'Found {len(comms)} communities.')
idx = 0
for i in comms:
    print(f'Community {idx} has {len(i)} nodes.')
    #print(i)
    idx = idx + 1
# Out:
# Found 1 communities.
# Community 0 has 2143 nodes.

# %% [markdown]
# # Small-world networks
#
# Does it have a low average shortest path?

# %%
if nx.is_strongly_connected(KG):
    print(f'Average shortest path length: {nx.average_shortest_path_length(KG)}')
else:
    print('KG is NOT strongly connected!')
# Out:
# KG is NOT strongly connected!

# %% [markdown]
# Does it have a high clustering coefficient?

# %%
# create weighted graph from M, as method is not implemented for MultiDiGraphs
DG = nx.DiGraph()
for u,v in KG.edges():
    if DG.has_edge(u,v):
        DG[u][v]['weight'] += 1
    else:
        DG.add_edge(u, v, weight=1)

ccs = nx.clustering(DG, weight='weight').values()

print(f"Clustering coefficient: {sum(ccs)/len(ccs)}")
# Out:
# Clustering coefficient: 0.0

# %% [markdown]
# # Some Centrality Measurements

# %%
# Degree centrality -- mean and stdev
dc = nx.degree_centrality(KG)
degrees = []
for k,v in dc.items():
    degrees.append(v)

print("DEGREE CENTRALITY")
print("=================")
print("The mean degree centrality is {}, with stdev {}".format(mean(degrees), statistics.stdev(degrees)))
print("The maximum node is {}, with value {}".format(max(dc, key=dc.get), max(dc.values())))
print("The minimum node is {}, with value {}".format(min(dc, key=dc.get), min(dc.values())))
histogram(dc)
print()

# PageRank -- mean and stdev
pc = nx.pagerank(KG)
degrees = []
for k,v in pc.items():
    degrees.append(v)

print("PAGERANK")
print("======================")
print("The mean network pagerank is {}, with stdev {}".format(mean(degrees), statistics.stdev(degrees)))
print("The maximum node is {}, with value {}".format(max(pc, key=pc.get), max(pc.values())))
print("The minimum node is {}, with value {}".format(min(pc, key=pc.get), min(pc.values())))
histogram(pc)
print()

# Betweenness centrality -- mean and stdev
bc = nx.betweenness_centrality(KG)
degrees = []
for k,v in bc.items():
    degrees.append(v)
print("BETWEENNESS CENTRALITY")
print("======================")
print("The mean betwenness centrality is {}, with stdev {}".format(mean(degrees), statistics.stdev(degrees)))
print("The maximum node is {}, with value {}".format(max(bc, key=bc.get), max(bc.values())))
print("The minimum node is {}, with value {}".format(min(bc, key=bc.get), min(bc.values())))
histogram(bc)
print()
# Out:
# DEGREE CENTRALITY
# =================
# The mean degree centrality is 0.001122800963595889, with stdev 0.025998199048061884
# The maximum node is http://dbpedia.org/resource/Oracle_Corporation, with value 1.2040149393090571
# The minimum node is http://dbpedia.org/resource/Zhongguancun, with value 0.00046685340802987864
# (1.2040149393090571, 0.003734827264239029, 0.002334267040149393, 0.0018674136321195146, 0.0014005602240896359, 0.0009337068160597573, 0.00046685340802987864) (1, 1, 7, 21, 83, 169, 1861)
# PAGERANK
# ======================
# The mean network pagerank is 0.00046663555762951924, with stdev 0.006830147799206441
# The maximum node is http://dbpedia.org/resource/Oracle_Corporation, with value 0.31633780829325003
# The minimum node is http://dbpedia.org/resource/Java_Desktop_System, with value 0.00019369021409684436
# (0.31633780829325003, 0.0014496610230282441, 0.0010310040867177774, 0.0006123471504073109, 0.00019369021409684436) (1, 7, 54, 513, 1568)
# BETWEENNESS CENTRALITY
# ======================
# The mean betwenness centrality is 9.758507442400435e-05, with stdev 0.004517461741506544
# The maximum node is http://dbpedia.org/resource/Oracle_Corporation, with value 0.20912481449064133
# The minimum node is http://dbpedia.org/resource/Java_Desktop_System, with value 0.0
# (0.20912481449064133, 0.0) (1, 2142)
