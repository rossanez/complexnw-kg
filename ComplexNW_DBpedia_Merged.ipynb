# %% [markdown]
# ## Comparing KGs to real-world complex networks
#
# Using a portion of *DBpedia* as target KG

# %% [markdown]
# # Environment Setup
#
# Install & imports

# %%
# Install required packages
import sys
# !pip install -q rdflib networkx matplotlib
# !{sys.executable} -m pip install rdflib networkx matplotlib --user

# Imports
from rdflib import Graph as RDFGraph
from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph
import networkx as nx
from networkx import Graph as NXGraph
import matplotlib.pyplot as plt
import statistics
import collections
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: rdflib in /usr/local/lib/python3.10/dist-packages (7.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)

# %% [markdown]
# Auxiliary functions

# %%
def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)

def histogram(l):
    degree_sequence = sorted([d for n, d in list(l.items())], reverse=True)
    degreeCount = collections.Counter(degree_sequence)
    deg, cnt = zip(*degreeCount.items())
    print(deg, cnt)

    fig, ax = plt.subplots()
    plt.bar(deg, cnt, width=0.80, color='b')

    plt.title("Histogram")
    plt.ylabel("Count")
    plt.xlabel("Value")
    ax.set_xticks([d + 0.4 for d in deg])
    ax.set_xticklabels(deg)

    plt.show()


def degree_histogram_directed(G, in_degree=False, out_degree=False):
    """Return a list of the frequency of each degree value.

    Parameters
    ----------
    G : Networkx graph
       A graph
    in_degree : bool
    out_degree : bool

    Returns
    -------
    hist : list
       A list of frequencies of degrees.
       The degree values are the index in the list.

    Notes
    -----
    Note: the bins are width one, hence len(list) can be large
    (Order(number_of_edges))

    Ref.: https://stackoverflow.com/a/62662992
    """
    nodes = G.nodes()
    if in_degree:
        in_degree = dict(G.in_degree())
        degseq=[in_degree.get(k,0) for k in nodes]
    elif out_degree:
        out_degree = dict(G.out_degree())
        degseq=[out_degree.get(k,0) for k in nodes]
    else:
        degseq=[v for k, v in G.degree()]
    dmax=max(degseq)+1
    freq= [ 0 for d in range(dmax) ]
    for d in degseq:
        freq[d] += 1
    return freq

# %% [markdown]
# ## Loading RDF model
#
# Pointing to a remote Turtle (*.ttl) file.

# %%
rg = RDFGraph()
rg.parse('http://www.ic.unicamp.br/~ra124136/kgs/dbpedia_merged_oracle_movie.ttl', format='ttl') # Turtle format

print("rdflib Graph loaded successfully with {} triples".format(len(rg)))
# Out:
# rdflib Graph loaded successfully with 6037 triples

# %% [markdown]
# ## Converting rdflib.Graph to networkx.MultiDiGraph
#
# KGs are directed graphs with the possibility of multiple paralell edges.

# %%
# Conversion of rdflib.Graph to networkx.MultiDiGraph
KG = rdflib_to_networkx_multidigraph(rg)
print("networkx Graph loaded successfully with length {}".format(len(KG)))
# Out:
# networkx Graph loaded successfully with length 5554

# %% [markdown]
# # General Network Metrics
#
# Network size and density

# %%
# Network size
print("NETWORK SIZE")
print("============")
print("The network has {} nodes and {} edges".format(KG.number_of_nodes(), KG.number_of_edges()))
print()

# Density
print("DENSITY")
print("============")
print("The network density is {}".format(nx.density(KG)))
print()
# Out:
# NETWORK SIZE
# ============
# The network has 5554 nodes and 6037 edges
#
# DENSITY
# ============
# The network density is 0.00019574362507077347

# %% [markdown]
# # Scale-free Networks
#
# Degree distribution -- Is it Poisson's or Power-law alike?

# %%
in_degree_freq = degree_histogram_directed(KG, in_degree=True)
out_degree_freq = degree_histogram_directed(KG, out_degree=True)
degrees = range(len(in_degree_freq))
plt.figure(figsize=(12, 8))
plt.loglog(range(len(in_degree_freq)), in_degree_freq, 'go-', label='in-degree')
plt.loglog(range(len(out_degree_freq)), out_degree_freq, 'bo-', label='out-degree')
plt.xlabel('Degree')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Are there HUBS available?

# %%
h, a = nx.hits(KG)

print("Hubs:")
print(sorted(h.items(), key=lambda x:x[1], reverse=True)) # Hubs - estimates the node value based on outgoing links.
print("The mean is {}, with stdev {}".format(mean(h.values()), statistics.stdev(h.values())))
print("The greatest hub is {}, with value {}".format(max(h, key=h.get), max(h.values())))
print("")
print("Authorities:")
print(sorted(a.items(), key=lambda x:x[1], reverse=True)) # Authorities - estimates the node value based on the incoming links
print("The mean is {}, with stdev {}".format(mean(a.values()), statistics.stdev(a.values())))
print("The greatest authority is {}, with value {}".format(max(a, key=a.get), max(a.values())))
# Out:
# Hubs:
# [(rdflib.term.URIRef('http://dbpedia.org/resource/Ten_Thirty-One_Pictures_Entertainment'), 0.0008693124611183777), (rdflib.term.URIRef('http://dbpedia.org/resource/Centropolis_Entertainment'), 0.0008693124611183777), (rdflib.term.URIRef('http://dbpedia.org/resource/Pece_Trajkovski_–_Brada'), 0.0008693124611183777), (rdflib.term.URIRef('http://dbpedia.org/resource/Sunset_Gower_Studios'), 0.0008693124611183777), (rdflib.term.URIRef('http://dbpedia.org/resource/Jacso_Group'), 0.0008693124611183777), (rdflib.term.URIRef('http://dbpedia.org/resource/DViant_Films'), 0.0008693124611183777), (rdflib.term.URIRef('http://dbpedia.org/resource/Melina_Petriella'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Hothat_Brishti'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Gormiti_Nature_Unleashed'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Movie_(disambiguation)'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Matthijs_van_de_Sande_Bakhuyzen'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Ami_Yamato'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Densha_Otoko'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Versailles_(album)'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Deedar_(1992_film)'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Something_Like_Happiness'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Jan_Decleir'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Kokkuri-san_(film)'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Hole_in_the_Moon'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Ek_Alag_Mausam'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Hood_of_the_Living_Dead'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Hiripoda_Wassa'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Tetchie_Agbayani'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Meera_Ke_Girdhar'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Up_for_the_Rising_Sun'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/IGN_Convention'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Fußball_ist_unser_Leben'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Il_Cuore_nel_Pozzo'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Frame_of_Mind_(film)'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Solidão,_Uma_Linda_História_de_Amor'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Sapne_Sajan_Ke'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Kakao_Entertainment'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Fighting_Back:_The_Rocky_Bleier_Story'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/TV_PinGuim'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/The_Man_Who_Saw_Tomorrow'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Lake_Windfall'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Sandra_Kerns'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Bara_no_Konrei_~Mayonaka_ni_Kawashita_Yakusoku~'), 0.0005795416407455851), (rdflib.term.URIRef("http://dbpedia.org/resource/L'est_Films_Group"), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Belvision_Studios'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/resource/Stylus_Magazine'), 0.0005795416407455851), (rdflib.term.URIRef('http://dbpedia.org/r ...
# The mean is 0.00018005041411596606, with stdev 0.00014615621546699352
# The greatest hub is http://dbpedia.org/resource/Ten_Thirty-One_Pictures_Entertainment, with value 0.0008693124611183777
#
# Authorities:
# [(rdflib.term.URIRef('http://dbpedia.org/resource/Movie'), 0.9974683566394431), (rdflib.term.URIRef('http://dbpedia.org/resource/Film'), 0.0005625874134476707), (rdflib.term.Literal('19374121', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), 0.00028129370672384324), (rdflib.term.Literal('Movie', lang='en'), 0.00028129370672384243), (rdflib.term.Literal('18', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#nonNegativeInteger')), 0.00028129370672383343), (rdflib.term.URIRef('http://en.wikipedia.org/wiki/Movie?oldid=331656496&ns=0'), 0.00028129370672383083), (rdflib.term.URIRef('http://dbpedia.org/ontology/MusicGenre'), 0.0002812937067238251), (rdflib.term.URIRef('http://en.wikipedia.org/wiki/Movie'), 0.0002812937067238204), (rdflib.term.Literal('331656496', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), 0.00028129370672381907), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Corporation'), 4.5229965697736515e-14), (rdflib.term.URIRef('http://dbpedia.org/resource/Dharam_Jeet'), 5.463719006442827e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/A_Snake_of_June'), 5.0633654082758223e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Rudy:_The_Rudy_Giuliani_Story'), 4.9271114624839145e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_(1981_film)'), 4.887643958806527e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Blonde_Comet'), 4.6969829989991526e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Though_None_Go_with_Me'), 4.6130682336689945e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/El_Húsar_de_la_Muerte'), 4.378233591801197e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Kad_budem_mrtav_i_beo'), 4.346646792681133e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Raji_Arasu'), 4.218151270261405e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Din_Tao:_Leader_of_the_Parade'), 4.092872545662908e-17), (rdflib.term.URIRef('http://dbpedia.org/class/yago/Company108058098'), 4.0914663175143796e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Aama_(film)'), 4.072687628388032e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Jay_Vijayan'), 4.0406410248018774e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Seetayya'), 3.996258916990846e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Prem_Granth'), 3.974096993543235e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Choices_of_the_Heart'), 3.966060404362915e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Master_Spy:_The_Robert_Hanssen_Story'), 3.898861115974897e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/System_Global_Area'), 3.8914890720278054e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Rahim_Fazal'), 3.878329288975887e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Imaandaar'), 3.878244158465245e-17), (rdflib.term.URIRef('http://bg.dbpedia.org/resource/Оракъл_(корпорация)'), 3.858435680452359e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Tujhe_Meri_Kasam'), 3.857444605912384e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Kilimanjaro:_How_to_spell_Love!'), 3.821856875003495e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Polytechnic_School_of_the_University_of_São_Paulo'), 3.780371338412762e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/The_Comrades_of_Summer'), 3.778665271414318e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Simba_Technologies'), 3.776204683985389e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Endgame_(1999_film)'), 3.757693534497728e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Cloudera'), 3.7331131798890885e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Regent_on_Broadway'), 3.7321411317388683e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Rebecca_Enonchong'), 3.7186154849417395e-17), (rdflib.term.URIRef('http://dbpedia.org/resource/Oracle_Identity_Management'), 3.6878805597538914e-17), (rdflib.term.URI ...
# The mean is 0.00018005041411595294, with stdev 0.0133843159707598
# The greatest authority is http://dbpedia.org/resource/Movie, with value 0.9974683566394431

# %% [markdown]
# # Communities
#
# Check for communities using the Clauset-Newman-Moore Algorithm (greedy modularity - applicable to directed graphs)

# %%
comms = nx.community.greedy_modularity_communities(KG)

print(f'Found {len(comms)} communities.')
idx = 0
for i in comms:
    print(f'Community {idx} has {len(i)} nodes.')
    #print(i)
    idx = idx + 1
# Out:
# Found 2 communities.
# Community 0 has 3411 nodes.
# Community 1 has 2143 nodes.

# %% [markdown]
# # Small-world networks
#
# Does it have a low average shortest path?

# %%
if nx.is_strongly_connected(KG):
    print(f'Average shortest path length: {nx.average_shortest_path_length(KG)}')
else:
    print('KG is NOT strongly connected!')
# Out:
# KG is NOT strongly connected!

# %% [markdown]
# Does it have a high clustering coefficient?

# %%
# create weighted graph from M, as method is not implemented for MultiDiGraphs
DG = nx.DiGraph()
for u,v in KG.edges():
    if DG.has_edge(u,v):
        DG[u][v]['weight'] += 1
    else:
        DG.add_edge(u, v, weight=1)

ccs = nx.clustering(DG,weight='weight').values()

print(f"Clustering coefficient: {sum(ccs)/len(ccs)}")
# Out:
# Clustering coefficient: 0.0

# %% [markdown]
# # Some Centrality Measurements

# %%
# Degree centrality -- mean and stdev
dc = nx.degree_centrality(KG)
degrees = []
for k,v in dc.items():
    degrees.append(v)

print("DEGREE CENTRALITY")
print("=================")
print("The mean degree centrality is {}, with stdev {}".format(mean(degrees), statistics.stdev(degrees)))
print("The maximum node is {}, with value {}".format(max(dc, key=dc.get), max(dc.values())))
print("The minimum node is {}, with value {}".format(min(dc, key=dc.get), min(dc.values())))
histogram(dc)
print()

# PageRank -- mean and stdev
pc = nx.pagerank(KG)
degrees = []
for k,v in pc.items():
    degrees.append(v)

print("PAGERANK")
print("======================")
print("The mean network pagerank is {}, with stdev {}".format(mean(degrees), statistics.stdev(degrees)))
print("The maximum node is {}, with value {}".format(max(pc, key=pc.get), max(pc.values())))
print("The minimum node is {}, with value {}".format(min(pc, key=pc.get), min(pc.values())))
histogram(pc)
print()

# Betweenness centrality -- mean and stdev
bc = nx.betweenness_centrality(KG)
degrees = []
for k,v in bc.items():
    degrees.append(v)
print("BETWEENNESS CENTRALITY")
print("======================")
print("The mean betwenness centrality is {}, with stdev {}".format(mean(degrees), statistics.stdev(degrees)))
print("The maximum node is {}, with value {}".format(max(bc, key=bc.get), max(bc.values())))
print("The minimum node is {}, with value {}".format(min(bc, key=bc.get), min(bc.values())))
histogram(bc)
print()
# Out:
# DEGREE CENTRALITY
# =================
# The mean degree centrality is 0.0003914872501415756, with stdev 0.010425398572788127
# The maximum node is http://dbpedia.org/resource/Movie, with value 0.6232667026832344
# The minimum node is http://dbpedia.org/resource/Tom_Lantos, with value 0.00018008283810552856
# (0.6232667026832344, 0.46443363947415817, 0.0014406627048442284, 0.0009004141905276428, 0.0007203313524221142, 0.0005402485143165856, 0.0003601656762110571, 0.00018008283810552856) (1, 1, 1, 7, 21, 89, 206, 5228)
# PAGERANK
# ======================
# The mean network pagerank is 0.00018005041411592977, with stdev 0.0036077696757229752
# The maximum node is http://dbpedia.org/resource/Movie, with value 0.23554300240961346
# The minimum node is http://dbpedia.org/resource/Tom_Lantos, with value 6.829654697841156e-05
# (0.23554300240961346, 0.11201980538649095, 0.03983422498259743, 0.019951260764787922, 0.0005089885349196899, 0.00036209120560593043, 0.00021519387629217099, 6.829654697841156e-05) (1, 1, 1, 7, 7, 54, 513, 4970)
# BETWEENNESS CENTRALITY
# ======================
# The mean betwenness centrality is 5.759895154026516e-06, with stdev 0.00041757482413171424
# The maximum node is http://dbpedia.org/resource/Oracle_Corporation, with value 0.031107461449557863
# The minimum node is http://dbpedia.org/resource/Tom_Lantos, with value 0.0
# (0.031107461449557863, 0.0008829962359054041, 0.0) (1, 1, 5552)
